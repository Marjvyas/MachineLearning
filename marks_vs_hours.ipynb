# %% [markdown]
# <a href="https://colab.research.google.com/github/Marjvyas/MachineLearning/blob/main/marks_vs_hours.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
data={'hours': [2.5, 5.1, 3.2, 8.5, 3.5, 1.5, 9.2, 5.5, 8.3, 2.7, 7.7, 5.9, 4.5, 3.3, 1.1, 8.9, 2.5, 1.9, 6.1, 7.4, 2.7, 4.8, 3.8, 6.9, 7.8],
      'scores': [21, 47, 27, 75, 30, 20, 88, 60, 81, 25, 85, 62, 41, 42, 17, 95, 30, 24, 67, 69, 30, 54, 35, 76, 86]}

# %%
df= pd.DataFrame(data)
df
# Out:
#     hours  scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
x=df[['hours']]
y=df['scores']

# %%
plt.scatter(x,y)
plt.xlabel('hours')
plt.ylabel('scores')
plt.title('hours vs score')
plt.show()

# %%
model=LinearRegression()
model.fit(x, y)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x)

# %%
plt.scatter(x, y, color='blue', label='Original Data')
plt.plot(x, y_pred, color='red', linewidth=2, label='Best Fit Line')
plt.xlabel('Hours Studied')
plt.ylabel('Marks Scored')
plt.title('Linear Regression: Hours vs Marks')
plt.legend()
plt.grid(True)
plt.show()

# %%
m=model.coef_
c=model.intercept_

# %%
print('slop: ',m[0])
print('intercept: ',c)
# Out:
# slop:  9.775803390787468
# intercept:  2.48367340537321
